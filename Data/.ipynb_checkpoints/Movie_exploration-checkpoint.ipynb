# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None  # default='warn'

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")

# %%
movies.head()
# Out:
#      budget                                             genres  \
# 0  25000000                      [{"id": 18, "name": "Drama"}]
# 1  20000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 2  12000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  60000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 4  64000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
#
#                                homepage      id  \
# 0                                   NaN     380
# 1  http://www.triggerfish.co.za/khumba/  172391
# 2                                   NaN     154
# 3                                   NaN   10047
# 4                                   NaN   12618
#
#                                             keywords original_language  \
# 0  [{"id": 30, "name": "individual"}, {"id": 791,...                en
# 1  [{"id": 209714, "name": "3d"}, {"id": 221034, ...                en
# 2  [{"id": 504, "name": "uss enterprise"}, {"id":...                en
# ...

# %%
genres = pd.DataFrame(columns=['id', 'name'])
for s in movies.genres:
    t = pd.read_json(s)
    genres = genres.append(t)

# %%
unique_genres = genres.drop_duplicates().set_index("id")

# %%
unique_genres
# Out:
#                   name
# id
# 18               Drama
# 16           Animation
# 12           Adventure
# 10751           Family
# 28              Action
# 878    Science Fiction
# 53            Thriller
# 36             History
# 10752              War
# 10749          Romance
# 9648           Mystery
# 99         Documentary
# 35              Comedy
# 14             Fantasy
# 80               Crime
# 27              Horror
# 37             Western
# 10402            Music
# 10770         TV Movie
# 10769          Foreign

# %%
unique_genres.to_csv("genre.csv")

# %%
movies.genres = movies.genres.apply(lambda x: pd.read_json(x)["id"].tolist() if "id" in x else [])

# %%
movies.genres
# Out:
# 0                              [18]
# 1                   [16, 12, 10751]
# 2                 [28, 12, 878, 53]
# 3           [12, 18, 28, 36, 10752]
# 4                       [18, 10749]
# 5       [28, 12, 18, 9648, 878, 53]
# 6                          [18, 53]
# 7                              [99]
# 8                          [18, 53]
# 9               [10751, 16, 12, 35]
# 10                    [12, 18, 878]
# 11                     [28, 12, 35]
# 12                    [28, 878, 12]
# 13                [28, 12, 878, 53]
# 14                [28, 12, 878, 53]
# 15                     [12, 14, 28]
# 16                [878, 28, 18, 53]
# 17                    [878, 12, 53]
# 18          [12, 10751, 16, 28, 35]
# 19                [878, 28, 53, 12]
# 20                    [12, 28, 878]
# 21                             [18]
# 22                 [18, 28, 80, 53]
# 23                    [18, 12, 878]
# 24          [28, 53, 878, 9648, 12]
# 25                  [16, 12, 10751]
# ...

# %%
keywords = pd.DataFrame(columns=['id', 'name'])
for s in movies.keywords:
    t = pd.read_json(s)
    keywords = keywords.append(t)

# %%
unique_keywords = keywords.drop_duplicates().set_index("id")

# %%
movies.keywords = movies.keywords.apply(lambda x: pd.read_json(x)["name"].tolist() if "name" in x else [])

# %%
prod = pd.DataFrame(columns=['id', 'name'])
for s in movies.production_companies:
    t = pd.read_json(s)
    prod = prod.append(t)

# %%
unique_prod = prod.drop_duplicates().set_index("id")

# %%
movies.production_companies = movies.production_companies.apply(lambda x: pd.read_json(x)["name"].tolist() if "name" in x else [])

# %%
movies.production_companies
# Out:
# 0                 [United Artists, Star Partners II Ltd.]
# 1                                 [Triggerfish Animation]
# 2                                    [Paramount Pictures]
# 3                            [Columbia Pictures, Gaumont]
# 4                                     [Columbia Pictures]
# 5       [Summit Entertainment, Mystery Clock Cinema, E...
# 6                                         [Making Movies]
# 7         [BIM Distribuzione, Fellowship Adventure Group]
# 8                            [Altavista Films, Zeta Film]
# 9        [Universal Pictures, Illumination Entertainment]
# 10      [Paramount Pictures, Legendary Pictures, Warne...
# 11      [Twentieth Century Fox Film Corporation, Marve...
# 12      [Marvel Studios, Moving Picture Company (MPC),...
# 13      [Village Roadshow Pictures, Kennedy Miller Pro...
# 14      [Universal Studios, Amblin Entertainment, Lege...
# 15        [Walt Disney Pictures, Jerry Bruckheimer Films]
# ...

# %%
lang = pd.DataFrame(columns=['iso_639_1', 'name'])
for s in movies.spoken_languages:
    t = pd.read_json(s)
    lang = lang.append(t)

# %%
unique_prod = lang.drop_duplicates()

# %%
movies.spoken_languages = movies.spoken_languages.apply(lambda x: pd.read_json(x)["iso_639_1"].tolist() if "iso" in x else [])

# %%
movies.spoken_languages
# Out:
# 0               [it, en]
# 1                   [en]
# 2                   [en]
# 3               [en, la]
# 4                   [en]
# 5                   [en]
# 6                   [en]
# 7               [ar, en]
# 8                   [es]
# 9                   [en]
# 10                  [en]
# 11                  [en]
# 12                  [en]
# 13                  [en]
# 14                  [en]
# 15                  [en]
# 16                  [en]
# 17                  [en]
# 18                  [en]
# 19                  [en]
# 20      [ro, en, de, ru]
# 21                  [en]
# 22              [en, zh]
# 23              [en, zh]
# 24          [en, ja, fr]
# 25                  [en]
# 26                  [en]
# 27              [en, es]
# 28                  [en]
# 29      [en, tr, el, zh]
#               ...
# 4773                [es]
# 4774                [en]
# 4775                [en]
# 4776                  []
# 4777                  []
# 4778    [nl, en, fr, de]
# ...

# %%
movies.production_countries = movies.production_countries.apply(lambda x: pd.read_json(x)["iso_3166_1"].tolist() if "iso" in x else [])

# %%
movies.columns
# Out:
# Index(['budget', 'genres', 'homepage', 'id', 'keywords', 'original_language',
#        'original_title', 'overview', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'vote_average',
#        'vote_count', 'Unnamed: 20'],
#       dtype='object')

# %%
movies.vote_count.head()
# Out:
# 0    1709.0
# 1      72.0
# 2     675.0
# 3     367.0
# 4      63.0
# Name: vote_count, dtype: float64

# %%
movies.to_csv("movie.csv")

# %%
movies.vote_count.head()
# Out:
# 0    1709.0
# 1      72.0
# 2     675.0
# 3     367.0
# 4      63.0
# Name: vote_count, dtype: float64

# %%
movies[movies.vote_average=="Con Air"]
# Out:
#        budget        genres homepage    id  \
# 588  75000000  [28, 53, 80]      NaN  1701
#
#                                               keywords original_language  \
# 588  [prison, ambush, helicopter, airport, gas stat...                en
#
#     original_title                                           overview  \
# 588        Con Air  When the government puts all its rotten crimin...
#
#      popularity                               production_companies  \
# 588   45.154631  [Jerry Bruckheimer Films, Kouf/Bigelow Product...
#
#         ...      release_date    revenue  runtime  spoken_languages    status  \
# 588     ...        1997-06-01  224012234    115.0              [en]  Released
#
#                             tagline                 title vote_average  \
# 588  They were deadly on the ground   Now they have wings      Con Air
#
#     vote_count  Unnamed: 20
# 588        6.5       1270.0
#
# [1 rows x 21 columns]

# %%
movies
# Out:
#          budget                       genres  \
# 0      25000000                         [18]
# 1      20000000              [16, 12, 10751]
# 2      12000000            [28, 12, 878, 53]
# 3      60000000      [12, 18, 28, 36, 10752]
# 4      64000000                  [18, 10749]
# 5      50000000  [28, 12, 18, 9648, 878, 53]
# 6             0                     [18, 53]
# 7       6000000                         [99]
# 8       2000000                     [18, 53]
# 9      74000000          [10751, 16, 12, 35]
# 10    165000000                [12, 18, 878]
# 11     58000000                 [28, 12, 35]
# 12    170000000                [28, 878, 12]
# 13    150000000            [28, 12, 878, 53]
# 14    150000000            [28, 12, 878, 53]
# 15    140000000                 [12, 14, 28]
# 16    170000000            [878, 28, 18, 53]
# 17    125000000                [878, 12, 53]
# 18    165000000      [12, 10751, 16, 28, 35]
# 19    155000000            [878, 28, 53, 12]
# ...

# %%
len(movies)
# Out:
# 4803
