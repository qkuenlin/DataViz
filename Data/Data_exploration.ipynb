# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None  # default='warn'

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")

# %%
movies.head()
# Out:
#      budget                                             genres  \
# 0  25000000                      [{"id": 18, "name": "Drama"}]
# 1  20000000  [{"id": 16, "name": "Animation"}, {"id": 12, "...
# 2  12000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  60000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
# 4  64000000  [{"id": 18, "name": "Drama"}, {"id": 10749, "n...
#
#                                homepage      id  \
# 0                                   NaN     380
# 1  http://www.triggerfish.co.za/khumba/  172391
# 2                                   NaN     154
# 3                                   NaN   10047
# 4                                   NaN   12618
#
#                                             keywords original_language  \
# 0  [{"id": 30, "name": "individual"}, {"id": 791,...                en
# 1  [{"id": 209714, "name": "3d"}, {"id": 221034, ...                en
# 2  [{"id": 504, "name": "uss enterprise"}, {"id":...                en
# ...

# %%
genres = pd.DataFrame(columns=['id', 'name'])
for s in movies.genres:
    t = pd.read_json(s)
    genres = genres.append(t)

# %%
len(genres)
# Out:
# 12160

# %%
unique_genres = genres.groupby(["name"]).size().to_frame(name = 'count').reset_index()

# %%
len(unique_genres)
# Out:
# 20

# %%
unique_genres
# Out:
#                name  count
# 0            Action   1154
# 1         Adventure    790
# 2         Animation    234
# 3            Comedy   1722
# 4             Crime    696
# 5       Documentary    110
# 6             Drama   2297
# 7            Family    513
# 8           Fantasy    424
# 9           Foreign     34
# 10          History    197
# 11           Horror    519
# 12            Music    185
# 13          Mystery    348
# 14          Romance    894
# 15  Science Fiction    535
# 16         TV Movie      8
# 17         Thriller   1274
# 18              War    144
# 19          Western     82

# %%
movies.budget.describe()
# Out:
# count    4.803000e+03
# mean     2.904504e+07
# std      4.072239e+07
# min      0.000000e+00
# 25%      7.900000e+05
# 50%      1.500000e+07
# 75%      4.000000e+07
# max      3.800000e+08
# Name: budget, dtype: float64

# %%
credits = pd.read_csv("tmdb_5000_credits.csv")

# %%
credits.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %%
crew = pd.DataFrame(columns=['credit_id', 'department', 'gender', 'id', 'job', 'name', 'movie_id'])
cast = pd.DataFrame(columns=['cast_id', 'character', 'credit_id', 'gender','id', 'name', 'order'])
for index, row in credits.iterrows():
    a = pd.read_json(row['cast'])
    a['movie_id'] = row['movie_id']
    c = pd.read_json(row['crew'])
    c['movie_id'] = row['movie_id']
    cast = cast.append(a)
    crew = crew.append(c)

# %%
crew.head()
# Out:
#                     credit_id  department gender    id  \
# 0.0  52fe48009251416c750aca23     Editing      0  1721
# 1.0  539c47ecc3a36810e3001f87         Art      2   496
# 2.0  54491c89c3a3680fb4001cf7       Sound      0   900
# 3.0  54491cb70e0a267480001bd0       Sound      0   900
# 4.0  539c4a4cc3a36810c9002101  Production      1  1262
#
#                           job movie_id               name
# 0.0                    Editor    19995  Stephen E. Rivkin
# 1.0         Production Design    19995        Rick Carter
# 2.0            Sound Designer    19995  Christopher Boyes
# 3.0  Supervising Sound Editor    19995  Christopher Boyes
# 4.0                   Casting    19995          Mali Finn

# %%
crew.reset_index(inplace=True, drop=True)

# %%
crew.head()
# Out:
#                   credit_id  department gender    id  \
# 0  52fe48009251416c750aca23     Editing      0  1721
# 1  539c47ecc3a36810e3001f87         Art      2   496
# 2  54491c89c3a3680fb4001cf7       Sound      0   900
# 3  54491cb70e0a267480001bd0       Sound      0   900
# 4  539c4a4cc3a36810c9002101  Production      1  1262
#
#                         job movie_id               name
# 0                    Editor    19995  Stephen E. Rivkin
# 1         Production Design    19995        Rick Carter
# 2            Sound Designer    19995  Christopher Boyes
# 3  Supervising Sound Editor    19995  Christopher Boyes
# 4                   Casting    19995          Mali Finn

# %%
def f(x):
    r = '['
    for i, s in enumerate(x):
        if i > 0:
            r = r + ','
        r = r + str(int(s))
    return r + ']'

# %%
crew2 = crew.groupby(['department', 'gender', 'id', 'job', 'name'])

# %%
crew2 = crew2.agg({'movie_id':f})

# %%
crew2.reset_index(inplace=True)

# %%
crew2.head()
# Out:
#   department  gender      id            job                     name  \
# 0     Actors       0   14445   Stunt Double              Leigh Walsh
# 1     Actors       0   16740   Stunt Double      Francois Grobbelaar
# 2     Actors       0   16741   Stunt Double  Mick 'Stuntie' Milligan
# 3     Actors       0  119183   Stunt Double         Giorgio Antonini
# 4        Art       0     370  Art Direction       Jack G. Taylor Jr.
#
#                       movie_id
# 0                        [813]
# 1                       [1372]
# 2                       [1372]
# 3                      [37056]
# 4  [5551,3683,66,9573,1598,70]

# %%
crew2.to_csv('crew.csv')

# %%
cast.head()
# Out:
#     cast_id            character                 credit_id gender     id  \
# 0.0     242           Jake Sully  5602a8a7c3a3685532001c9a      2  65731
# 1.0       3              Neytiri  52fe48009251416c750ac9cb      1   8691
# 2.0      25  Dr. Grace Augustine  52fe48009251416c750aca39      1  10205
# 3.0       4        Col. Quaritch  52fe48009251416c750ac9cf      2  32747
# 4.0       5         Trudy Chacon  52fe48009251416c750ac9d3      1  17647
#
#      movie_id                name order
# 0.0   19995.0     Sam Worthington     0
# 1.0   19995.0         Zoe Saldana     1
# 2.0   19995.0    Sigourney Weaver     2
# 3.0   19995.0        Stephen Lang     3
# 4.0   19995.0  Michelle Rodriguez     4

# %%
cast.reset_index(inplace=True, drop=True)

# %%
cast.head()
# Out:
#   cast_id            character                 credit_id gender     id  \
# 0     242           Jake Sully  5602a8a7c3a3685532001c9a      2  65731
# 1       3              Neytiri  52fe48009251416c750ac9cb      1   8691
# 2      25  Dr. Grace Augustine  52fe48009251416c750aca39      1  10205
# 3       4        Col. Quaritch  52fe48009251416c750ac9cf      2  32747
# 4       5         Trudy Chacon  52fe48009251416c750ac9d3      1  17647
#
#    movie_id                name order
# 0   19995.0     Sam Worthington     0
# 1   19995.0         Zoe Saldana     1
# 2   19995.0    Sigourney Weaver     2
# 3   19995.0        Stephen Lang     3
# 4   19995.0  Michelle Rodriguez     4

# %%
cast.to_csv("cast2.csv")

# %%
cast2 = cast.groupby(['gender', 'id', 'name'])

# %%
cast2 = cast2.agg({'movie_id':f})

# %%
cast2.reset_index(inplace=True)

# %%
cast2.sample(5)
# Out:
#        gender       id         name  movie_id
# 7162        0   170941   Paul Geier   [11873]
# 24181       0  1727015   Andrew Bee  [297761]
# 26992       0  1824465   Jay Norman    [1725]
# 21867       0  1558642  Ava Sambora   [89492]
# 46996       2    90172   Brett Marx   [23479]

# %%
cast2.to_csv('cast.csv')

# %%
l_link = []
[l_link.append(i) for x in crew2.movie_id for i in x.strip("[").strip("]").split(",")]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
len(l_link)
# Out:
# 129581
